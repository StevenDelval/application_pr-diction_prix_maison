# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df_preparation = pd.read_csv("csv/df_preparation.csv")

# %%
df_preparation.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_living_carre', 'sqft_lot',
#        'floors', 'view', 'condition', 'grade', 'grade_carre', 'sqft_above',
#        'sqft_above_carre', 'sqft_basement', 'sqft_basement_carre', 'quartier',
#        'is_renovated', 'price'],
#       dtype='object')

# %%
feature = df_preparation.columns[0:-1]
target = 'price'
X =df_preparation[feature]
y = df_preparation[target]

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_living_carre  sqft_lot  floors  \
# 0             3       1.00         1180            1392400      5650     1.0
# 1             3       2.25         2570            6604900      7242     2.0
# 2             2       1.00          770             592900     10000     1.0
# 3             4       3.00         1960            3841600      5000     1.0
# 4             3       2.00         1680            2822400      8080     1.0
# ...         ...        ...          ...                ...       ...     ...
# 21608         3       2.50         1530            2340900      1131     3.0
# 21609         4       2.50         2310            5336100      5813     2.0
# 21610         2       0.75         1020            1040400      1350     2.0
# 21611         3       2.50         1600            2560000      2388     2.0
# 21612         2       0.75         1020            1040400      1076     2.0
#
#        view  condition  grade  grade_carre  sqft_above  sqft_above_carre  \
# 0         0          3      7           49        1180           1392400
# 1         0          3      7           49        2170           4708900
# 2         0          3      6           36         770            592900
# 3         0          5      7           49        1050           1102500
# 4         0          3      8           64        1680           2822400
# ...     ...        ...    ...          ...         ...               ...
# 21608     0          3      8           64        1530           2340900
# 21609     0          3      8           64        2310           5336100
# 21610     0          3      7           49        1020           1040400
# 21611     0          3      8           64        1600           2560000
# 21612     0          3      7           49        1020           1040400
#
#        sqft_basement  sqft_basement_carre  quartier  is_renovated
# 0                  0                    0         0             0
# 1                400               160000         0             1
# 2                  0                    0         0             0
# 3                910               828100         0             0
# 4                  0                    0         0             0
# ...              ...                  ...       ...           ...
# 21608              0                    0         0             0
# 21609              0                    0         0             0
# 21610              0                    0         0             0
# 21611              0                    0         0             0
# 21612              0                    0         0             0
#
# [21613 rows x 16 columns]

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %% [markdown]
# # Feature scaling

# %%
standarisation = StandardScaler()
X = pd.DataFrame(standarisation.fit_transform(X),columns=X.columns)

# %% [markdown]
# # Separation en données d'entrainement et de test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = 0.8)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_living_carre  sqft_lot  \
# 5268  -0.398737  -1.447464    -0.555193          -0.500234 -0.231701
# 16909 -0.398737   0.500221    -0.326539          -0.370116 -0.099155
# 16123 -0.398737  -0.798235    -1.077829          -0.736388 -0.126630
# 12181  0.676485   0.500221     0.141657          -0.052783 -0.193821
# 12617 -0.398737   0.500221    -0.304762          -0.356873 -0.249736
# ...         ...        ...          ...                ...       ...
# 13123  1.751707   3.746361     2.047104           1.944303  1.906878
# 19648 -1.473959   0.500221    -0.740293          -0.593619 -0.334262
# 9845  -0.398737   0.175607     0.304981           0.074006 -0.003790
# 10799  0.676485  -0.149007     0.315869           0.082754  1.486207
# 2732   0.676485   0.175607     0.326757           0.091540  0.027258
#
#          floors      view  condition     grade  grade_carre  sqft_above  \
# 5268  -0.915427 -0.305759   0.907554 -0.558836    -0.573550   -0.867546
# 16909 -0.915427 -0.305759   0.907554  0.291916     0.207900   -0.698479
# 16123 -0.915427 -0.305759  -0.629187  0.291916     0.207900   -0.843394
# 12181  0.936506 -0.305759  -0.629187  0.291916     0.207900    0.509146
# 12617  0.936506 -0.305759  -0.629187 -0.558836    -0.573550   -0.662250
# ...         ...       ...        ...       ...          ...         ...
# 13123  0.936506 -0.305759  -0.629187  1.993418     2.083380    2.622489
# 19648  0.936506 -0.305759  -0.629187  0.291916     0.207900   -0.758860
# 9845  -0.915427 -0.305759   0.907554  1.142667     1.093543    0.690290
# 10799  0.936506 -0.305759   0.907554  0.291916     0.207900    0.702366
# 2732  -0.915427 -0.305759  -0.629187 -0.558836    -0.573550   -0.299963
#
#        sqft_above_carre  sqft_basement  sqft_basement_carre  quartier  \
# 5268          -0.660701       0.471097            -0.048347 -0.326062
# 16909         -0.583707       0.629266             0.069068  3.066900
# 16123         -0.650280      -0.658681            -0.440255 -0.326062
# 12181          0.241220      -0.658681            -0.440255 -0.326062
# 12617         -0.565979       0.606670             0.051354 -0.326062
# ...                 ...            ...                  ...       ...
# 13123          2.845652      -0.658681            -0.440255 -0.326062
# 19648         -0.612290      -0.116388            -0.349959 -0.326062
# 9845           0.406568      -0.658681            -0.440255 -0.326062
# 10799          0.417977      -0.658681            -0.440255 -0.326062
# 2732          -0.364812       1.239346             0.665864 -0.326062
#
#        is_renovated
# 5268      -0.210135
# 16909     -0.210135
# 16123     -0.210135
# 12181     -0.210135
# 12617     -0.210135
# ...             ...
# 13123     -0.210135
# 19648     -0.210135
# 9845      -0.210135
# 10799     -0.210135
# 2732      -0.210135
#
# [17290 rows x 16 columns]

# %% [markdown]
# # Export en csv

# %%
X_train.to_csv('csv/X_train.csv',index=False)
X_test.to_csv('csv/X_test.csv',index=False)
y_train.to_csv('csv/y_train.csv',index=False)
y_test.to_csv('csv/y_test.csv',index=False)
