# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df_preparation = pd.read_csv("csv/df_preparation.csv")

# %%
df_preparation.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'floors', 'waterfront', 'view',
#        'grade', 'sqft_above', 'sqft_basement', 'sqft_living15', 'quartier',
#        'is_renovated', 'price'],
#       dtype='object')

# %%
feature = df_preparation.columns[0:-1]
target = 'price'
X =df_preparation[feature]
y = df_preparation[target]

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  floors  waterfront  view  grade  \
# 0             3       1.00         1180     1.0           0     0      7
# 1             3       2.25         2570     2.0           0     0      7
# 2             2       1.00          770     1.0           0     0      6
# 3             4       3.00         1960     1.0           0     0      7
# 4             3       2.00         1680     1.0           0     0      8
# ...         ...        ...          ...     ...         ...   ...    ...
# 21591         3       2.50         1530     3.0           0     0      8
# 21592         4       2.50         2310     2.0           0     0      8
# 21593         2       0.75         1020     2.0           0     0      7
# 21594         3       2.50         1600     2.0           0     0      8
# 21595         2       0.75         1020     2.0           0     0      7
#
#        sqft_above  sqft_basement  sqft_living15  quartier  is_renovated
# 0            1180              0           1340         0             0
# 1            2170            400           1690         0             1
# 2             770              0           2720         0             0
# 3            1050            910           1360         0             0
# 4            1680              0           1800         0             0
# ...           ...            ...            ...       ...           ...
# 21591        1530              0           1530         0             0
# 21592        2310              0           1830         0             0
# 21593        1020              0           1020         0             0
# 21594        1600              0           1410         0             0
# 21595        1020              0           1020         0             0
#
# [21596 rows x 12 columns]

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21591    360000.0
# 21592    400000.0
# 21593    402101.0
# 21594    400000.0
# 21595    325000.0
# Name: price, Length: 21596, dtype: float64

# %% [markdown]
# # Feature scaling

# %%
standarisation = StandardScaler()
X = pd.DataFrame(standarisation.fit_transform(X),columns=X.columns)

# %% [markdown]
# # Separation en données d'entrainement et de test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size = 0.8)

# %%
X_train
# Out:
#        bedrooms  bathrooms  sqft_living    floors  waterfront      view  \
# 6882   0.694809   0.499567     0.740286  0.937385   -0.087207 -0.305723
# 7019  -0.411272   0.824672     0.936343  0.937385   -0.087207 -0.305723
# 5938  -0.411272   0.174461    -0.692019  0.937385   -0.087207 -0.305723
# 98    -0.411272  -0.475751    -0.294459 -0.915591   -0.087207 -0.305723
# 21300 -1.517353   0.499567    -0.436056  2.790361   -0.087207 -0.305723
# ...         ...        ...          ...       ...         ...       ...
# 13123 -1.517353  -0.475751    -0.904414 -0.915591   -0.087207 -0.305723
# 19648 -0.411272   0.174461    -1.178894  0.937385   -0.087207 -0.305723
# 9845  -0.411272  -0.475751    -0.675681  0.937385   11.466944  4.913564
# 10799 -0.411272  -1.451069    -1.046011 -0.915591   -0.087207 -0.305723
# 2732   0.694809  -0.475751     0.282820 -0.915591   -0.087207 -0.305723
#
#           grade  sqft_above  sqft_basement  sqft_living15  quartier  \
# 6882  -0.560817    1.173513      -0.658992       0.997276 -0.326204
# 7019   1.996311    1.390972      -0.658992       1.639409 -0.326204
# 5938  -0.560817   -0.590317      -0.331429      -0.841561 -0.326204
# 98    -0.560817   -0.699046       0.696440      -0.491306 -0.326204
# 21300  1.143935   -0.131238      -0.658992      -0.447524 -0.326204
# ...         ...         ...            ...            ...       ...
# 13123 -0.560817   -0.650722      -0.658992      -0.447524  3.065565
# 19648 -0.560817   -1.196785      -0.207181      -1.442831 -0.326204
# 9845   0.291559   -0.807776       0.109086      -0.024300 -0.326204
# 10799 -0.560817   -0.807776      -0.658992      -0.243209 -0.326204
# 2732   0.291559   -0.215805       0.990116       0.705397 -0.326204
#
#        is_renovated
# 6882      -0.210221
# 7019      -0.210221
# 5938      -0.210221
# 98        -0.210221
# 21300     -0.210221
# ...             ...
# 13123     -0.210221
# 19648     -0.210221
# 9845      -0.210221
# 10799     -0.210221
# 2732      -0.210221
#
# [17276 rows x 12 columns]

# %% [markdown]
# # Export en csv

# %%
X_train.to_csv('csv/X_train.csv',index=False)
X_test.to_csv('csv/X_test.csv',index=False)
y_train.to_csv('csv/y_train.csv',index=False)
y_test.to_csv('csv/y_test.csv',index=False)
